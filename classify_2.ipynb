# %%
import pandas as pd
import numpy as np
import torch
from torchtext.data import Field
from torchtext.data import TabularDataset
from torchtext.data import Iterator, BucketIterator
import torch.autograd as autograd
import tqdm

from csv_handle import save_csv

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support, classification_report, confusion_matrix

# %%
source_file="data/fitocracy_posts.csv"
version = "_fito"
train_filename, valid_filename, test_filename = save_csv(source_file=source_file, version=version, full=True)

# %%
source_file="data/facebook_equal.csv"
version = "_fb"
train_filename_2, valid_filename_2, test_filename_2 = save_csv(source_file=source_file, version=version, full=True)

# %%
train = pd.read_csv('data/train_fito.csv')
valid = pd.read_csv('data/valid_fito.csv')
test = pd.read_csv('data/test_fito.csv')

# %%
train_2 = pd.read_csv('data/train_fb.csv')
valid_2 = pd.read_csv('data/valid_fb.csv')
test_2 = pd.read_csv('data/test_fb.csv')

# %%
# Build the classifier
text_train = train['comment_text'].values
text_test = test['comment_text'].values

y_train = train['gender'].values
y_test = test['gender'].values

# %%
# Build the classifier
text_train_2 = train_2['comment_text'].values
text_test_2 = test_2['comment_text'].values

y_train_2 = train_2['gender'].values
y_test_2 = test_2['gender'].values

# %%
# Vectorize sentences
vec = TfidfVectorizer(stop_words='english', max_features=2000)
X_train = vec.fit_transform(text_train)
X_test = vec.transform(text_test)

# %%
# Vectorize sentences
X_train_2 = vec.fit_transform(text_train_2)
X_test_2 = vec.transform(text_test_2)

# %%
clf = LogisticRegression(warm_start=True)
clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=True)

# %%
saved_right = []

for x,y,text in zip(X_test, y_test, text_test):
    
    r = clf.predict(x)    
    if r == y:
        saved_right.append([x, y, text])

# %%
saved_right
# Out:
# [[<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 8 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow! Your story/journey is awesome and I wish you all the best as you continue.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 13 stored elements in Compressed Sparse Row format>,
#   0,
#   "Dunno if I should stick to doing a pull-up and a chin-up each time I go through the doorway with the bar or if I should just aim for ten of each a day. I'm worried if I stick to the doorway one, I'll start avoiding that door. Thoughts?"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow! following back!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks of the props!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 8 stored elements in Compressed Sparse Row format>,
#   0,
#   'So close to level 35. What should i do to log 102 points during my afternoon at work? Recommendations welcomed. Encouraged, even.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   "Thanks for the follow! How's it going? How your goals coming along?"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Kik Messenger users group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 14 stored elements in Compressed Sparse Row format>,
#   1,
#   "Really?  I did it again. Need my eyes checked I think! Can't get those workouts entered right the first time when I use the app on my phone!!  Ugh."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 18 stored elements in Compressed Sparse Row format>,
#   1,
#   'Boom! 500grams off my goal weight!!!!! Love seeing results! Hard work really does pay off!!!! :) 18 days till I look amazing in my wedding dress x'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'thx 4 the follow!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Nice trail run; 15k of goodness.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the You Are Your Own Gym - by Mark Lauren group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 24 stored elements in Compressed Sparse Row format>,
#   1,
#   "If anyone's wondering, the reason I only do one-legged pushups now - and only supported by my right leg - is that I seem to have brought long-term damage to the tendon behind my left knee, or something, while doing regular pushups. No idea how to make that go away. It's been bothering me since July this year and I have to be careful not to ever let that knee hyperextend, even by mistake (I've also had a hyperextension problem my whole life). If anyone has any healing suggestions, let me know."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   "How's everyone doing?!?"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow! Following back.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'has just transformed into a Fitocracy Hero!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 10 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hi Martinette, how are you doing? Sharing the x-mas with someone special again after all you have gone through? Wishes you best best for the holidays :-) Merry Christmas, Kenneth'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 10 stored elements in Compressed Sparse Row format>,
#   1,
#   'Thanks for the follow! Mother of 3!! WOW! I watch 2 kids 3 times a week and have my hands full. How do you manage 3?! :O'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'thanks for the follow got u on the follow back'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 0 stored elements in Compressed Sparse Row format>, 0, 'Hay.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 23 stored elements in Compressed Sparse Row format>,
#   1,
#   "Pulling myself up by the bootstraps because I have to - complaining never solved any of the world's problems. I need to reclaim my positive attitude and determination. I have battled bigger demons than this - grief, depression, weight loss - and a letter on a piece of paper says nothing for my worth as a person, no matter how important it may seem right now. I'm just going through a rough patch right now, but it'll pass. I'll make it pass."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 13 stored elements in Compressed Sparse Row format>,
#   1,
#   'Dislocated my shoulder a little over a week ago. FINALLY able to run without pain! Swimming and lifting is gonna take a bit longer :('],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow back :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hey thanks for following..... Following back! Btw good back shot in that pp!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 18 stored elements in Compressed Sparse Row format>,
#   0,
#   "Did my run shortly after coming home from work. The rain turned to ice about halfway through; I'll be glad when this little winter storm passes over the east coast. Tomorrow should be nicer.Got all my grocery shopping done for tomorrow. HAPPY THANKSGIVING, EVERYONE!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Weight Loss group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'The dreaded skipping rope.... but apparently it will help develop my footwork for my fights. Go figure!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'My profile pic is Maddie, and she has a cute website: http://maddieonthings.com/'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the kind words and follow!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 12 stored elements in Compressed Sparse Row format>,
#   1,
#   "This seems to say to add the weight of the barbell.. maybe I misunderstood you, but I'm gonna go change that =)  http://www.fitocracy.com/forum/topic/12732/"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   "just joined the '13 New Years resolutions....  group!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'Thanks for the follow Ryan! You are now officially the closest fitocrat to me, as I work in Leeds and live in Wakefield!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'I would really like to know how you have 8000 more fitocracy points than I do! Cheat much?'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow JG :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow:) following back!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow back'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Congrats on 120 workouts!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   1,
#   "I did it!!!! How's it feel to be beaten by your baby sister!!!!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the No Barbie Weights Here group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 0 stored elements in Compressed Sparse Row format>,
#   0,
#   'DO SOMETHING!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 14 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow, PoppaG and following back!!!  Looks like you have quite a goal by hitting level 24 on push-ups alone.  Keep it up man!  I will be cheering for you!!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'just joined the Couch to 5K group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   "It's good to catch up on all the good work you've been doing! Yay for all those pushups."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow! *clicks Follow Now*'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   'I am sure you will soon pass me again with your regular beastly workouts, but I am going to savor this moment while it lasts.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Flew through another level like yesterday, zoooom!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'MFP invades Fitocracy!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'thanks for props!)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'thanks for the follow, following back :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'Mmmmm...chocolate-dipped people?  Yes please.Thanks for the follow.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'Happy New Year!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks fo the FB! ;)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Holy prop attack...thanks!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'just joined the Couch to 5K group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Runners group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'Started working out because I had the apartment to myself. Shortly afterwards people come home >...<'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Liking the new PP!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'THanks for the follow!! following back!! :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'hey, how do you link endomondo to my fitness pal?'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   0,
#   "First weigh in coming up on Monday. Pretty excited about it. Already noticing that some of my clothes aren't as tight as they used to be."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 0 stored elements in Compressed Sparse Row format>,
#   0,
#   'You can do it cabbage!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   '20 mile bike ride first one for a few months ouch ouch ouch.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 8 stored elements in Compressed Sparse Row format>,
#   1,
#   'Ewwww!! My form is awful!! I recorded my Olympic lifts today - guess who pulls during her snatches!  This girl.... /sigh. Back to the basics..'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'thanks for the follow, following back'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Spoon Counters group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Holy apropalypse thank you for the massive props!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Cheers! Following back!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 8 stored elements in Compressed Sparse Row format>,
#   1,
#   'Was supposed to workout, catch up on stuff... Insteas, I ate and slept for 12 hours. Argh'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thank you for all the props Beautiful!!!!!!!!!!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'thanks! that was one hell of a prop bomb!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   "Why is it that I haven't crossed the path of an asshole on Fitocracy yet? People all seem nice and kind and smart. Where is the catch?"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 13 stored elements in Compressed Sparse Row format>,
#   1,
#   "Holy crap, it's spider man! Those are some badass climbing sessions you've been logging. Pretty sure after 3 hours, my forearms would melt. Especially with overhangs, those things are my nemesis."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thank you for the follow! :) What are your fitness goals?I see you love the erg as well :D'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   1,
#   'far too hot for anything today, must go find fruit for smoothies :D'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   1,
#   "I'm not too far behind ya, ma! Soon I'll be at Lvl 8, just you wait! (Haha, I rhymed)"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Legs tomorrow lets do it'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 15 stored elements in Compressed Sparse Row format>,
#   0,
#   'Amazing what you can do with well rested legs and some grit. I annihilated my old elliptical record and notched 3.05 miles in 30 minutes, at 10 resistance...my legs feel like rubber but it was awesome to smash that record. Now I boost it to 11 and start over...'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'OMG LOVE THE BEACH BABE MUSCLE SHOT!!!! hahahhahahah'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 20 stored elements in Compressed Sparse Row format>,
#   1,
#   "Resting up today for my Half Marathon tomorrow. About to go fetch my race number, then a braai with friends (though I won't be eating any meat). A bit worried about the weather. Gale force winds today that are meant to continue tomorrow and spitting rain. :( Running in the wind is SO tough."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'This. Is. Adorable.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for all the props!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for all the props !'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 11 stored elements in Compressed Sparse Row format>,
#   1,
#   "It's hard to measure. Looks like I went down an inch around the top of my thigh this week. Gained a tiny bit on my bicep. That's the only change."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the I Love a Good Challenge! group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   '100 more props until 1,000 props!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'oh whaaaaaat where have you been??'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hi there Nick :-)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 17 stored elements in Compressed Sparse Row format>,
#   1,
#   'I am probably the most excited person on the planet right now.  Not only did I get to see Carrie Fisher live two weeks ago, I just now got home from seeing Colin Mochrie and Brad Sherwood.  I was like fifteen feet away from my childhood improv heroes.  I really might explode with glee.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 8 stored elements in Compressed Sparse Row format>,
#   1,
#   'I went to the forums to figure out what the "Nuke" button next to the "Prop" is on some posts, cannot find it. I assume it is to prop everything on the page or something?'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   "so I was gonna do SS again with my friend, but now he's dead. so kettlebell all the way!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow back :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   'New PP! Looking good there (keep kicking people in the head)!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   0,
#   'I have 4 tests in the next two days and with studying and everything my schedule is completely thrown off. How do you guys usually deal with the interference of real life'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 10 stored elements in Compressed Sparse Row format>,
#   1,
#   'Does 9 hours of quadbiking and clay pigeon shooting count as exercise or just a fun day out? And if the former, any ideas on logging?! Exhausted!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hey thanks for the follow and creating the group. My kids are a big part of the reason I am getting in shape.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 12 stored elements in Compressed Sparse Row format>,
#   0,
#   'Workouts temporarily interrupted by water heater crisis, but the satisfaction of taking my new unit from the floor above, arms extended, and then moving it slowly down through the crawlspace hatch until it rested gently on the ground at my feet -- awesome.  Functional strength rules.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow - following back to prop your progress and cheer your accomplishments :-)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'thanks for the prop bomb!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the No Barbie Weights Here group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 12 stored elements in Compressed Sparse Row format>,
#   1,
#   "I'm giving up caffeine after drinking black tea like water for the last decade and three to four cups of coffee a day for over two years.  I didn't know headaches could be this bad."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the You Are Your Own Gym - by Mark Lauren group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'You are a super fan of exercise lol keep working hard'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   "I'M FINALLY 18!!! WHOOO!!!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'thanks for the follow, looking awesome!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the No Barbie Weights Here group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'O helo. <3  Glad you joined the new fitness fad.  No points for watching Gordo do TKD though :D'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 14 stored elements in Compressed Sparse Row format>,
#   1,
#   "Ahhhh the app just flipped out when I tried to change something and made me 100lbs heavier and a few centimetres shorter! Then it wouldn't let me fix it despite trying about ten times. Had to use fitocracy in my browser to edit. Whaaaaats happening?!!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the prop bomb... I got my 1000 badge!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 8 stored elements in Compressed Sparse Row format>,
#   1,
#   'Thank you for the follow! Following back! I love how your workouts are so diverse! Plenty of everything! :) Keep up the great work!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow. Following you back.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   1,
#   'Ito yun sinasabi ko last weekend! 4 weeks for you, 8 weeks for friends & family, 12 weeks for the rest of the world :) #keepgoing http://pinterest.com/pin/203858320602937230/'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   1,
#   'vacation time *dance* *dance* *pizza*'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'how many calories does doing scales on piano earn me?'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 10 stored elements in Compressed Sparse Row format>,
#   0,
#   "Night all...time for that 0Period in life that builds the strength that we work so hard for...SLEEEEEP!! Then it's gym time @ 7:30 am...gotta love it!!!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   "My asthma didn't stop me today!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the followup! ^^'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 19 stored elements in Compressed Sparse Row format>,
#   0,
#   "Hey Brother Mike.... when do you hit the Bay Area again?  Gotta be soon.  We're looking forward to seeing you and Gheng.  Irene and I are heading to Kuching in July.  Hope to meet Russ's friend there, maybe get in a little training/learning."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   1,
#   'I hope to make great progress'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 8 stored elements in Compressed Sparse Row format>,
#   0,
#   'This is pretty sweet.  Very easy to track workouts I like that.  Achievements are funny too.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for all the props.. No workouts from u.. All good??'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   "wowow! thanks so much for the props! I can see why they're so popular; made my day!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'To cut or to smolov and eat 4000 calories? Such a tough decision.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   "you are killing it.  I'm going to need you to chill out."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 13 stored elements in Compressed Sparse Row format>,
#   0,
#   "Ok Zach, you win, I'm not doing anything else today and there's no way to log VBS rec time. And thanks for all 98 meaningless comments. Congrats buddy, I'll see you in LA!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   "Thanks for the follow! Killer before and after you've got there. :)"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'So whilst the exquisite melody brings forth warmth to thy nether regions my pantaloons remain absent of moisture.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'just joined the Couch to 5K group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   "I've been cleaning the house for 6 hours! How many points is that??"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 0 stored elements in Compressed Sparse Row format>,
#   0,
#   'Where are you from?'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Once PVP starts, you are going down.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'Good morning. Hope you had a great weekend bud.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   'http://www.lift-run-bang.com/2014/02/underrated-and-overrated-concepts-in_18.html?m=1'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 25 stored elements in Compressed Sparse Row format>,
#   0,
#   "Does anyone know the best way to stop trapezius tension headaches, they are killing my upperbody workout to the point where my vision blurs. I've tried different stretches and worked my form closely, I take in about 2L of water a day and don't think it's that as I've been doing these workouts for the last 10 months with no issues. Any help would be great."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow back and for all of the tips! :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the No Barbie Weights Here group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Is it me or the fito app for droid is really buggy!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'Best profile pic :D'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>, 0, 'Badass PP!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 11 stored elements in Compressed Sparse Row format>,
#   0,
#   "I know it's not news, but the exercise isn't the difficult part. It's gathering up the initiative to /do/ the exercise that's hard! (That's me, obliquely saying that I really don't want to exercise tonight.)"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   "Halloween idea - if you're dressing up for Halloween, take a picture of you in your costume and post it as your profile pic by Monday."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   "Too bad you can't enter ring exercises on here."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Cheers for the props and follow.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow, following back!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   'oh yea i meant to ask you, are you doing 6000 squats with a time limit?'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   "Thanks for the follow, following back based on your 'about me'.  Welcome to fitocracy"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Dat forearm porn. Someone hand me a fan and cold wash cloth.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hi. Thanks for ALL the props!!!!!!!!!!!!!!!!!!!!!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'thx for the follow, following back.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 11 stored elements in Compressed Sparse Row format>,
#   0,
#   'All you crazy ripped people out there, what are some good exercises to do in the gym to lose the hip fat? (asides from cardio), any tips?'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'thanks for the follow, following back'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'If I can lose 3 more pounds, I will be back to the lowest point I was at last year (which is not saying much, but hey...down is down).'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Healthy Eating group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'AMAZING! GOTCHA BACK!!!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'Thanks a bunch for the follow!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   "thanks for the follow and all those props! How 'bout them Cowboys?!!! ;)"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 21 stored elements in Compressed Sparse Row format>,
#   0,
#   'Nursing a shoulder injury. Will be eliminating all press exercises (in my case bench press, pushup, clean and press), Chin-ups and Pull-ups to reduce pressure on my shoulders. On monday I will (carefully) attempt to squat and deadlift at reduced weight, in the hopes that my shoulder will be strong enough as a supporting muscle alone. I will be adding a tremendous amount of swimming to my regimen.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   1,
#   'Thank you for the follow :-)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow. Following back!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'Managed a 160kg deadlift single today.  Race still on?'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 14 stored elements in Compressed Sparse Row format>,
#   0,
#   "Sooo I will be running my first full marathon (Richmond) the day before you are running your half... I must admit i'm a hair nervous about the distance I've never run more then a half, and it's coming up!!! Do you feel ready?"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 8 stored elements in Compressed Sparse Row format>,
#   0,
#   "Ok it's that time. My form. Criticize it.Bench press: http://youtu.be/Ha1unegOPvcPendlay Row: http://youtu.be/f3nRlBGoi8gSquat: http://youtu.be/UrYRDbJvBIg"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow, following back.  Good luck with your goals...  More squats = super strong...'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Rowers group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 13 stored elements in Compressed Sparse Row format>,
#   1,
#   "Many thanks to the guy moving a ton of stuff who lost a 3' stuffed monkey out of the back of his truck today. I ran him down and shouted 'your monkey escaped!' I was laughing so hard.  So extra points for the ab work out."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow :-) >'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 10 stored elements in Compressed Sparse Row format>,
#   1,
#   'Learning it pays off not to give up right when it hurts.. Feeling the burn but so worth it!! :) finally getting heart back into my workouts'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'Ummm you are gorgeous.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   1,
#   "HIIIIIIIIIIII! Guess who's back!?"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 28 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hi and thanks for the follow.  Just to let you know, I was a smoker (about a pack a day) and overweight verging on obese at the age of 32.  With a lot of determination, discipline, and a little help from the couch to 5k (and a diet journal like at myfitnesspal.com), I lost 80+ pounds in about a year and a half and ran a marathon in 2 years (34 years old).  It can be done, just stick with it!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'Did you not cycle yesterday? No negative cheating.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'thx for the follow :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 18 stored elements in Compressed Sparse Row format>,
#   0,
#   "Awesome pics. Great size. Look thick. Solid. Tight. Keep us all posted on your continued progress with any new progress pics or vid clips. Show us what you got man. Wanna see how freakin' huge, solid, thick and tight you can get. Thanks for the motivation."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   0,
#   'From one fellow asian to another thanks for always consistently propping my work. I appreciate it. You look great BTW =)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'Looks like I get to run in the rain tomorrow. Oh joy.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow man!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the props!!!! A nice day it was'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow, fb! Awesome goals, I know bad habits can be misery to break. Keep it up!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'PROPS BOOOOOOOOOOOOOMB'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 15 stored elements in Compressed Sparse Row format>,
#   1,
#   "I haven't been on Fito for a while... I've been pretty busy, haven't measured workouts to track (I still worked out but didn't take note of what I did), and sometimes the site wouldn't work on my computer. :S I'm back on track now! Helloooo"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   1,
#   "Hey NYC! I'm hosting a Children's Miracle Network Fundraiser on Sunday at BOUNCE in Chelsea from 3-7 pm.  Stop by and support CMN and check out my fitness progress! :)"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 22 stored elements in Compressed Sparse Row format>,
#   1,
#   'I feel so motivated this morning,it is my weigh in day and I lost 5 lbs from last week to now!  It feels so good to finally see that number going down again.  Day four of x-train fit at home here i come!!!!!  And my official weight went from 210.8 last Sunday to 205.9 today!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Ice Cream group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'I-i- miss you'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'Super excited to start working with heavier weights! :D'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   "I just accidentally deleted your post on my feed.  :(   I'm sorry!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the No Barbie Weights Here group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'welcome! your already level 2!!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow back : )'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the FB :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'look at that bein followed.  :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'Oh where, oh where is our sarah-ayars?You are hearted much here!!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   "I bloody need propping up after that! It's so hot, nearly blacked out on the last squat.."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 27 stored elements in Compressed Sparse Row format>,
#   0,
#   "You shall never beat me in Fitocracy! I have the ability to do nothing all day but play video games and do random sets of pull ups! Haha. I don't know about you but I'm having Dan/Finch time withdrawls. And isn't this kind of what you and I were talking about earlier this summer, having our attribute points go up? Sweet. And.... Rod Toughcurls and the bench press are on tonight in the promise-land!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   0,
#   'Well needed resting period. Gonna be ready to tear up some body weight reps tomorrow!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 22 stored elements in Compressed Sparse Row format>,
#   1,
#   "I have a terrible cold.  My chest hurts and I have a dry throat so if I take too deep of a breath, I have a coughing fit, so exercising is out of the question, as shallow breathing generally isn't great for working out.  And my congestion is getting worse.  Ugh.  Terrible time to get sick, I'm just about done with my training for my job and can actually start."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   'I broke my leg in one place and my ankle in two places. I am out of derby for the season :('],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   "Thx for all the props! Good motivation for tomorrow's work out."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 11 stored elements in Compressed Sparse Row format>,
#   1,
#   'Does anyone else think there should be an option for "chasing 5 kids all over a playground and spray park for a couple hours?"  I know I torched some calories out there, I should be able to log it somewhere'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hi, I\'m Troy McClure. You may remember me from such educational films as "Two Minus Three Equals Negative Fun" and "Firecrackers: The Silent Killer'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 8 stored elements in Compressed Sparse Row format>,
#   0,
#   'I got 1/3 of the way thru logging a workout but lost the will. Bye bye Fitocracy - it was fun but it\'s not quite "sticky" enough to keep me here.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'http://i.imgur.com/AXn1C.jpg'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
# ...
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow! FB!! :D'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   1,
#   "This is a little frustrating b/c all the workouts I do aren't listed here.  But otherwise this is pretty cool :)"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   1,
#   'Love your pic!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'I hear warming up is really good to help the low back.... ;)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   'thanks for the follow... following back and looking forward to propping your progress :-)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Wow! Prop bomb! Thanks!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Impossible to find a weightlifting gym in Amsterdam it would appear'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow, following back.  Good luck with the 5K!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'THANKS FOR THE PROP BOMB!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the No Barbie Weights Here group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 13 stored elements in Compressed Sparse Row format>,
#   1,
#   'Following back, welcome!  A great group to join is the Fitocracy Library:  https://www.fitocracy.com/group/16419/?chatter  . Under the "About" tab there is a link to a spreadsheet LOADED with links to articles, includes a bunch of search terms etc.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the love lady! Back at you.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'Track snowboarding and see what happens haha'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'so much props!! thanks E!!   : D'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hey, thanks for the follow back :) Nice progress on those Barbell Squats!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the followback, dang paleo, I gotta be better at it.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   "the site's too bright and stuff now. lol"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'OMG cannot believe how my butt muscles hurt!!!!!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hey whatsup? Welcome to fitocracy :P'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow, following back!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'Mate I love this thing.... Keep up the hard work matey'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'that skiing is really pushing you ahead of me...'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 15 stored elements in Compressed Sparse Row format>,
#   0,
#   "Props!  Thanks for the squat/dead tips too - I think they're helping. Trying the Mobility WOD group exercises as well.  Hope everything is going well... awesome workouts as usual!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the awesome prop bomb'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 10 stored elements in Compressed Sparse Row format>,
#   1,
#   "I fear I may have injured my ankle.  Trying to get in with a doctor to get an x-ray.  No swelling, but pain is at about a 3 while I'm walking, and when I touch the area the pain jumps to a 9.  Maybe I tore a ligament?"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow ! Back at you :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Had to follow after all those props! Thanks for the fb.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'just joined the Couch to 5K group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   "Don't give up on your weight loss goals! You gotta keep fighting!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Protein group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'Oh man, I feel like hammered shit after swimming those laps.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'just joined the Lady Lifters group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   '>tfw Camelbro always props your workouts'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>, 0, 'Hey there!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   0,
#   'I finished out the week with 2.5 miles.  Nice solid finish.  Time for a Day of Rest!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 15 stored elements in Compressed Sparse Row format>,
#   0,
#   "Well.... after 5 days of taking it easy from gall bladder surgery, had to do a little workout at home.  Anyone have any good workouts to get back into the groove at the gym after a surgery.  I don't want to hurt myself and have a setback, but I am looking for some good workouts to get back into the groove safely."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 18 stored elements in Compressed Sparse Row format>,
#   1,
#   "Self esteem at an all time low today- probably has to do with size 12 jeans that I can't fit into any more.  *sigh*  Trying to keep the positive, and get to the gym four days a week, but damn.  Sometimes it's just hard to do."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'just joined the Couch to 5K group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Atheists, Humanists, and Freethinkers group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the WTF - Welcome to Fitocracy group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 11 stored elements in Compressed Sparse Row format>,
#   0,
#   'One good thing about all the snow- the roads are nice and quiet. @MissG and I may be anble to drive into Nottingham tomorrow without getting stressed and arguing. I would be the first time but it just might happen :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   1,
#   "Is getting way too carried away on the forums, so I'm going to shut up now!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   0,
#   'just joined the Fitocracy Injury Recovery Room group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   0,
#   'Sweet tat, I should be getting another myself real soon, thanks for following!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>, 0, "I don't even"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'You know the grammar nazi in me always winces when I read "She\'s profile". Clearly it should be "Her profile".'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow. Following back.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'Nice profile pic!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   1,
#   'Did insanity at 5:45 am today despite losing an hour from the time zone switch.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Canadian National Capital Region (Ottawa-Gatineau) group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'Great new pic, Finnie!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'New PP I see, looking solid...very solid and beastly indeed!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Followed for the swimsuit update  :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   1,
#   'Hey there! Nice to see you. You are an ass-kicker. :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 13 stored elements in Compressed Sparse Row format>,
#   0,
#   'Hey.. How do I record the "Overhead Press" with Fitocracy? It\'s not showing me that exercise here.I recorded it as a "Push Press", since it sounds similar, but i\'m not sure if that\'s the correct term. +MK'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 18 stored elements in Compressed Sparse Row format>,
#   1,
#   "Dragged myself our of bed to work out, thinking it would help wake me up and get me energized (as it usually would), but instead, I just feel like I've been beat up. Boooooo. I'm either run down and fighting something, or already succumbing. Meanwhile, workmen are using power tools in my house.  There is nowhere to hide and sleep."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thought you were catching up with your posts......'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the No Barbie Weights Here group!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 6 stored elements in Compressed Sparse Row format>,
#   1,
#   'hello my vegan friend :)  bike ride again soon !'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for all the prop love. Appreciated.'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'Happy birthday indeed!  And thanks for the props!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   0,
#   'I just dropped the prop bomb on you. Woot. :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   1,
#   'OMG TEACHING DANCE FOR EIGHT HOURS IN ONE DAY IS FUN YOU GUISE NO REALLY'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   1,
#   "it's good to see you back on here! :)"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 4 stored elements in Compressed Sparse Row format>,
#   0,
#   'So you want to see what my routine is, you should go look at my profile. ;)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'thanks for following...when there is someone behind you it makes you less likely to stop ;)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the props!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1 stored elements in Compressed Sparse Row format>,
#   0,
#   'Welcome aboard!'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   0,
#   "You're Level 4and already? Hell... Im screwed. Some of the more developed athletes on the site seriously put 2 to 3 thousand points down a day. Good work dood!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'cheers for the follow, following back'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 3 stored elements in Compressed Sparse Row format>,
#   0,
#   'Thanks for the follow and the propane! followed back'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 7 stored elements in Compressed Sparse Row format>,
#   1,
#   'Took a week off due to family emergency and a nasty chest infection. Easing back in slowly. :)'],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 9 stored elements in Compressed Sparse Row format>,
#   1,
#   "Thanks for the follow! My son's music teacher had a quad bypass last spring and has gotten into such good shape since then. Good for you!"],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 19 stored elements in Compressed Sparse Row format>,
#   0,
#   "So I want to know something about you:I'm always curious as to how people found me and or why they chose to follow me, so what's your reason?What kind of goals do you have for fitness?Are you color blind? I've know quite a few guys who are namely an ex that thought my purple shirt was blue thought pink was purple. And my husband has a hard time with greens and browns."],
#  [<1x2000 sparse matrix of type '<class 'numpy.float64'>'
#   	with 5 stored elements in Compressed Sparse Row format>,
#   1,
#   'just joined the Fit Angels group!'],
#  ...]

# %%
clf.fit(X_train_2, y_train_2)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=True)

# %%
lost = []

for x,y,text in saved_right:
    r = clf.predict(x)    
    if r != y:
        lost.append([x, y, text])

# %%
lost
# Out:
# []

# %%
len(saved_right)
# Out:
# 28253

# %%
len(y_train_2), len(y_train)
# Out:
# (48000, 191121)

# %%
y_test_pred_2 = clf.predict(X_test_2)
y_test_pred = clf.predict(X_test)

# %%
print("\n~~TEST~~")
print(classification_report(y_test, y_test_pred))

print("\n~~TEST 2~~")
print(classification_report(y_test_2, y_test_pred_2))
# Out:
# ~~TEST~~
#               precision    recall  f1-score   support
#
#            0       0.52      0.57      0.55     29483
#            1       0.47      0.42      0.45     26989
#
#    micro avg       0.50      0.50      0.50     56472
#    macro avg       0.50      0.50      0.50     56472
# weighted avg       0.50      0.50      0.50     56472
#
#
# ~~TEST 2~~
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81      7962
#            1       0.81      0.80      0.80      8038
#
#    micro avg       0.81      0.81      0.81     16000
#    macro avg       0.81      0.81      0.81     16000
# weighted avg       0.81      0.81      0.81     16000
